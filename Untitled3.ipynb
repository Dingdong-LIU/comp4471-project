# %%
import pandas as pd
import collections
from imblearn.over_sampling import RandomOverSampler
import matplotlib.pyplot as plt

# %%
# initial set up
import tensorflow as tf
import tensorflow.keras
import numpy as np
import os
from glob import glob
import cv2
from sklearn.model_selection import train_test_split
from PIL import Image
import skimage
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt

# %%
import os
from tensorflow import keras

print(tf.version.VERSION)
# Out:
# 2.2.0

# %%
checkpoint_path = "../training_2/cp-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
print(checkpoint_dir)
# Out:
# ../training_2

# %%
# setting a gpu
gpus= tf.config.list_physical_devices('GPU')
print(gpus)
tf.config.experimental.set_memory_growth(gpus[0], True)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# define plot process function
def plot_process(acc, val_acc, loss, val_loss):
    plt.figure(figsize=(8, 8))
    plt.subplot(2, 1, 1)
    plt.plot(acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.ylabel('Accuracy')

    plt.title('Training and Validation Accuracy')

    plt.subplot(2, 1, 2)
    plt.plot(loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.ylabel('Cross Entropy')

    plt.title('Training and Validation Loss')
    plt.xlabel('epoch')
    plt.show()

# %%
def preprocessing_resize(pixels):
    a = []
    
    for i in range(len(pixels)):
            image_string = (pixels)[i].split(' ') 
            image_data = np.asarray(image_string, dtype=np.uint8).reshape(48,48,1)
#             image_data = cv2.resize(image_data, dsize=(160, 160), interpolation=cv2.INTER_CUBIC)
#             image_data = image_data.reshape(160, 160, 1)
            image_data2 = cv2.merge((image_data, image_data, image_data))
            a.append(image_data2)

    return a

# %%
def load_CKPLUS48():
    label_names = ['anger', 'contempt', 'disgust', 'fear', 'happy', 'sadness', 'surprise']
    images_arr = []
    labels_arr = []
    ini_path = '../Facial expression/data/CK+48'

    for i in range(len(label_names)):
        temp_path = os.path.join(ini_path, label_names[i])
        datas = glob(os.path.join(temp_path, '*.png'))
        for data in datas:
            img = Image.open(data)
            img = img.resize((160, 160))
            img = skimage.img_as_float(img)
            img2 = cv2.merge((img,img,img))

            images_arr.append(img2)
            labels_arr.append(i)
    if (len(images_arr) == 0):
        print("No data loaded")
        return
    print("Successfully find {} data and {} labels".format(len(images_arr), len(labels_arr)))
    print("Each of shape: {}".format(images_arr[0].shape))
    
    train_data, test_data, train_labels, test_labels = train_test_split(images_arr, labels_arr, test_size = 0.2, random_state = 13)
    test_labels = np.asarray(test_labels, dtype=np.float32)
    train_labels = np.asarray(train_labels, dtype=np.float32)
    test_data = np.asarray(test_data, dtype=np.float32)
    train_data = np.asarray(train_data, dtype=np.float32)
    
    print ("X_train shape: " + str(train_data.shape))
    print ("y_train shape: " + str(train_labels.shape))
    print ("X_val shape: " + str(test_data.shape))
    print ("y_val shape: " + str(test_labels.shape))
    
    return train_data, train_labels, test_data, test_labels

# %%
def load_dataset2():
    train_csv = pd.read_csv('../Facial expression/data/data_b/train.csv')
    
    oversample = RandomOverSampler(sampling_strategy='auto')

    X_over, y_over = oversample.fit_resample((train_csv.pixels).values.reshape(-1, 1), train_csv.emotion)

    a = np.array(y_over)
    
    y_over = pd.Series(y_over)
    y_over= y_over.values.reshape(len(y_over),1)
    
    y_over = to_categorical(y_over)

    X_train,X_val,y_train,y_val = train_test_split(X_over,y_over, test_size=0.2)
    
    X_train = pd.Series(X_train.flatten())
    X_train = np.array(preprocessing_resize(X_train))
    
    X_val = pd.Series(X_val.flatten())
    X_val = np.array(preprocessing_resize(X_val))
    
    
    print ("X_train shape: " + str(X_train.shape))
    print ("y_train shape: " + str(y_train.shape))
    print ("X_val shape: " + str(X_val.shape))
    print ("y_val shape: " + str(y_val.shape))
    
    return X_train, y_train, X_val, y_val

# %%
def plot_process(acc, val_acc, loss, val_loss):
    plt.figure(figsize=(8, 8))
    plt.subplot(2, 1, 1)
    plt.plot(acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.ylabel('Accuracy')

    plt.title('Training and Validation Accuracy')

    plt.subplot(2, 1, 2)
    plt.plot(loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.ylabel('Cross Entropy')

    plt.title('Training and Validation Loss')
    plt.xlabel('epoch')
    plt.show()

# %%
# X_train, y_train, X_val, y_val = load_CKPLUS48()

# %%
# y_val_catagorized = to_categorical(y_val)
# y_train_catagorized = to_categorical(y_train)
# print("y_val_categorized shape" , y_val_catagorized.shape)
# print("y_train_categorized shape" , y_train_catagorized.shape)

# %%
# for image, _ in train_dataset.take(1):
#   plt.figure(figsize=(10, 10))
#   first_image = image[0]
#   for i in range(9):
#     ax = plt.subplot(3, 3, i + 1)
#     augmented_image = data_augmentation(tf.expand_dims(first_image, 0))
#     plt.imshow(augmented_image[0].numpy())
#     plt.axis('off')

# %%
X_train, y_train, X_val, y_val = load_dataset2()
# Out:
# X_train shape: (40404, 48, 48, 3)
# y_train shape: (40404, 7)
# X_val shape: (10101, 48, 48, 3)
# y_val shape: (10101, 7)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val))

# %%
BATCH_SIZE = 64
SHUFFLE_BUFFER_SIZE = 100

train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
val_dataset = val_dataset.batch(BATCH_SIZE)

# %%
# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1,
                                                save_freq=3160)

# %%
image_resize = tf.keras.Sequential([
    tf.keras.layers.experimental.preprocessing.Resizing(160,160),
])

# %%
IMG_SHAPE = (160, 160) + (3,)
base_model = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')
base_model.trainable = False

# %%
image_batch, label_batch = next(iter(train_dataset))
feature_batch = image_resize(image_batch)
feature_batch = base_model(feature_batch)
print(feature_batch.shape)
# Out:
# (64, 5, 5, 1280)

# %%
# add global average and feature average layer
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
feature_batch_average = global_average_layer(feature_batch)
print(feature_batch_average.shape)
# Out:
# (64, 1280)

# %%
# add dense layer to recieve output
prediction_layer = tf.keras.Sequential([
    tf.keras.layers.Dense(128),
    tf.keras.layers.Dense(7),
])

prediction_batch = prediction_layer(feature_batch_average)
print(prediction_batch.shape)
# Out:
# (64, 7)

# %%
inputs = tf.keras.Input(shape=(48, 48, 3))
x = image_resize(inputs)
x = base_model(x, training=False)
x = global_average_layer(x)
x = tf.keras.layers.Dropout(0.2)(x)
outputs = prediction_layer(x)
model = tf.keras.Model(inputs, outputs)

model.save_weights(checkpoint_path.format(epoch=0))

# %%
base_learning_rate = 0.0001
model.compile(optimizer=tf.keras.optimizers.Adam(lr=base_learning_rate),
              loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 48, 48, 3)]       0
# _________________________________________________________________
# sequential (Sequential)      (None, 160, 160, 3)       0
# _________________________________________________________________
# mobilenetv2_1.00_160 (Model) (None, 5, 5, 1280)        2257984
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1280)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1280)              0
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 7)                 164871
# =================================================================
# Total params: 2,422,855
# Trainable params: 164,871
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
loss0, accuracy0 = model.evaluate(val_dataset)
print("initial loss: {:.2f}".format(loss0))
print("initial accuracy: {:.2f}".format(accuracy0))
# Out:
# 158/158 [==============================] - 6s 40ms/step - loss: 3.0539 - accuracy: 0.1321
# initial loss: 3.05
# initial accuracy: 0.13

# %%
initial_epochs = 30
history = model.fit(train_dataset,
                    epochs=initial_epochs,
                    validation_data=val_dataset,
                    callbacks=[cp_callback])
# Out:
# Epoch 1/30
# 632/632 [==============================] - 30s 48ms/step - loss: 1.9673 - accuracy: 0.2530 - val_loss: 1.6852 - val_accuracy: 0.3526
# Epoch 2/30
# 632/632 [==============================] - 30s 48ms/step - loss: 1.7259 - accuracy: 0.3362 - val_loss: 1.6129 - val_accuracy: 0.3860
# Epoch 3/30
# 632/632 [==============================] - 30s 48ms/step - loss: 1.6509 - accuracy: 0.3677 - val_loss: 1.5891 - val_accuracy: 0.3983
# Epoch 4/30
# 632/632 [==============================] - 30s 48ms/step - loss: 1.6143 - accuracy: 0.3838 - val_loss: 1.5606 - val_accuracy: 0.4058
# Epoch 5/30
# 632/632 [==============================] - 30s 48ms/step - loss: 1.5945 - accuracy: 0.3932 - val_loss: 1.5463 - val_accuracy: 0.4149
# Epoch 6/30
# 632/632 [==============================] - 30s 48ms/step - loss: 1.5777 - accuracy: 0.4013 - val_loss: 1.5292 - val_accuracy: 0.4221
# Epoch 7/30
# 632/632 [==============================] - 30s 48ms/step - loss: 1.5619 - accuracy: 0.4075 - val_loss: 1.5290 - val_accuracy: 0.4208
# Epoch 8/30
# 632/632 [==============================] - 30s 48ms/step - loss: 1.5580 - accuracy: 0.4076 - val_loss: 1.5131 - val_accuracy: 0.4294
# Epoch 9/30
# 632/632 [==============================] - 30s 48ms/step - loss: 1.5459 - accuracy: 0.4159 - val_loss: 1.5037 - val_accuracy: 0.4337
# Epoch 10/30
# 632/632 [==============================] - 30s 48ms/step - loss: 1.5450 - accuracy: 0.4167 - val_loss: 1.5014 - val_accuracy: 0.4318
# Epoch 11/30
# 632/632 [==============================] - 30s 48ms/step - loss: 1.5395 - accuracy: 0.4165 - val_loss: 1.5015 - val_accuracy: 0.4359
# Epoch 12/30
# 632/632 [==============================] - 30s 48ms/step - loss: 1.
40
# 632/632 [==============================] - 30s 48ms/step - loss: 1.4963 - accuracy: 0.4354 - val_loss: 1.4621 - val_accuracy: 0.4548
# Epoch 38/40
# 632/632 [==============================] - 30s 47ms/step - loss: 1.4946 - accuracy: 0.4365 - val_loss: 1.4647 - val_accuracy: 0.4496
# Epoch 39/40
# 631/632 [============================>.] - ETA: 0s - loss: 1.4984 - accuracy: 0.4338
# Epoch 00039: saving model to ../training_1/cp.ckpt
# 632/632 [==============================] - 30s 48ms/step - loss: 1.4984 - accuracy: 0.4339 - val_loss: 1.4589 - val_accuracy: 0.4535
# Epoch 40/40
# 632/632 [==============================] - 30s 48ms/step - loss: 1.4944 - accuracy: 0.4357 - val_loss: 1.4578 - val_accuracy: 0.4513

# %%
histories[index] = history
acc = histories[1].history['accuracy'] + histories[2].history['accuracy']
val_acc = histories[1].history['val_accuracy'] + histories[2].history['val_accuracy']

loss = histories[1].history['loss'] + histories[2].history['loss']
val_loss = histories[1].history['val_loss'] + histories[2].history['val_loss']
plot_process(acc, val_acc, loss, val_acc)
index = 3

# %%
index = 3
fine_tune_epochs = 10
total_epochs += fine_tune_epochs

history = model.fit(train_dataset, 
                    epochs=total_epochs, 
                    initial_epoch=history.epoch[-1], 
                    validation_data=val_dataset,
                   callbacks=[cp_callback])

histories[index] = history
# Out:
# Epoch 40/50
# 632/632 [==============================] - 30s 48ms/step - loss: 1.5019 - accuracy: 0.4326 - val_loss: 1.4572 - val_accuracy: 0.4560
# Epoch 41/50
# 632/632 [==============================] - 30s 48ms/step - loss: 1.4970 - accuracy: 0.4353 - val_loss: 1.4520 - val_accuracy: 0.4585
# Epoch 42/50
# 632/632 [==============================] - 30s 48ms/step - loss: 1.4940 - accuracy: 0.4357 - val_loss: 1.4642 - val_accuracy: 0.4529
# Epoch 43/50
# 632/632 [==============================] - 30s 48ms/step - loss: 1.4956 - accuracy: 0.4358 - val_loss: 1.4566 - val_accuracy: 0.4546
# Epoch 44/50
# 632/632 [==============================] - 30s 48ms/step - loss: 1.4969 - accuracy: 0.4343 - val_loss: 1.4640 - val_accuracy: 0.4497
# Epoch 45/50
# 632/632 [==============================] - 30s 48ms/step - loss: 1.4941 - accuracy: 0.4371 - val_loss: 1.4602 - val_accuracy: 0.4527
# Epoch 46/50
# 632/632 [==============================] - 30s 48ms/step - loss: 1.4978 - accuracy: 0.4342 - val_loss: 1.4564 - val_accuracy: 0.4510
# Epoch 47/50
# 632/632 [==============================] - 30s 48ms/step - loss: 1.4895 - accuracy: 0.4368 - val_loss: 1.4433 - val_accuracy: 0.4619
# Epoch 48/50
# 632/632 [==============================] - 30s 48ms/step - loss: 1.4919 - accuracy: 0.4364 - val_loss: 1.4528 - val_accuracy: 0.4560
# Epoch 49/50
# 632/632 [==============================] - 30s 48ms/step - loss: 1.4943 - accuracy: 0.4374 - val_loss: 1.4515 - val_accuracy: 0.4551
# Epoch 50/50
# 632/632 [==============================] - 30s 48ms/step - loss: 1.4950 - accuracy: 0.4336 - val_loss: 1.4605 - val_accuracy: 0.4548

# %%
acc += history.history['accuracy']
val_acc += history.history['val_accuracy']

loss += history.history['loss']
val_loss += history.history['val_loss']

plot_process(acc, val_acc, loss, val_acc)

# %%
index = 4
fine_tune_epoches = 5
total_epochs += fine_tune_epochs

history = model.fit(train_dataset, 
                    epochs=total_epochs, 
                    initial_epoch=history.epoch[-1], 
                    validation_data=val_dataset,
                   callbacks=[cp_callback])

histories[index] = history
# Out:
# Epoch 50/60
# 632/632 [==============================] - 30s 48ms/step - loss: 1.4872 - accuracy: 0.4397 - val_loss: 1.4546 - val_accuracy: 0.4552
# Epoch 51/60
# 632/632 [==============================] - 30s 48ms/step - loss: 1.4950 - accuracy: 0.4348 - val_loss: 1.4533 - val_accuracy: 0.4525
# Epoch 52/60
# 632/632 [==============================] - 30s 48ms/step - loss: 1.4892 - accuracy: 0.4378 - val_loss: 1.4619 - val_accuracy: 0.4484
# Epoch 53/60
# 632/632 [==============================] - 30s 48ms/step - loss: 1.4951 - accuracy: 0.4329 - val_loss: 1.4599 - val_accuracy: 0.4501
# Epoch 54/60
# 631/632 [============================>.] - ETA: 0s - loss: 1.4916 - accuracy: 0.4372
# Epoch 00054: saving model to ../training_1/cp-0054.ckpt
# 632/632 [==============================] - 30s 48ms/step - loss: 1.4916 - accuracy: 0.4372 - val_loss: 1.4576 - val_accuracy: 0.4541
# Epoch 55/60
# 632/632 [==============================] - 30s 48ms/step - loss: 1.4896 - accuracy: 0.4366 - val_loss: 1.4574 - val_accuracy: 0.4529
# Epoch 56/60
# 632/632 [==============================] - 30s 48ms/step - loss: 1.4915 - accuracy: 0.4345 - val_loss: 1.4516 - val_accuracy: 0.4563
# Epoch 57/60
# 632/632 [==============================] - 30s 48ms/step - loss: 1.4894 - accuracy: 0.4389 - val_loss: 1.4472 - val_accuracy: 0.4580
# Epoch 58/60
# 632/632 [==============================] - 30s 48ms/step - loss: 1.4874 - accuracy: 0.4389 - val_loss: 1.4555 - val_accuracy: 0.4544
# Epoch 59/60
# 631/632 [============================>.] - ETA: 0s - loss: 1.4892 - accuracy: 0.4390
# Epoch 00059: saving model to ../training_1/cp-0059.ckpt
# 632/632 [==============================] - 30s 48ms/step - loss: 1.4892 - accuracy: 0.4389 - val_loss: 1.4445 - val_accuracy: 0.4603
# Epoch 60/60
# 632/632 [==============================] - 30s 48ms/step - loss: 1.4860 - accuracy: 0.4391 - val_loss: 1.4559 - val_accuracy: 0.4499

# %%
acc += history.history['accuracy']
val_acc += history.history['val_accuracy']

loss += history.history['loss']
val_loss += history.history['val_loss']

plot_process(acc, val_acc, loss, val_acc)

# %%
base_model.trainable = True

# Let's take a look to see how many layers are in the base model
print("Number of layers in the base model: ", len(base_model.layers))

# # Fine-tune from this layer onwards
fine_tune_at = 100

# Freeze all the layers before the `fine_tune_at` layer
for layer in base_model.layers[:fine_tune_at]:
    layer.trainable =  False
# Out:
# Number of layers in the base model:  155

# %%
model.compile(loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
              optimizer = tf.keras.optimizers.RMSprop(lr=base_learning_rate/10),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 48, 48, 3)]       0
# _________________________________________________________________
# sequential (Sequential)      (None, 160, 160, 3)       0
# _________________________________________________________________
# mobilenetv2_1.00_160 (Model) (None, 5, 5, 1280)        2257984
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1280)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1280)              0
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 7)                 164871
# =================================================================
# Total params: 2,422,855
# Trainable params: 2,027,463
# Non-trainable params: 395,392
# _________________________________________________________________

# %%
len(model.trainable_variables)
# Out:
# 60

# %%
index = 5
fine_tune_epochs = 10
total_epochs += fine_tune_epochs

history = model.fit(train_dataset, 
                    epochs=total_epochs, 
                    initial_epoch=history.epoch[-1], 
                    validation_data=val_dataset,
                   callbacks=[cp_callback])

histories[index] = history
# Out:
# Epoch 60/70
# 632/632 [==============================] - 43s 68ms/step - loss: 1.4336 - accuracy: 0.4575 - val_loss: 1.4018 - val_accuracy: 0.4634
# Epoch 61/70
# 632/632 [==============================] - 43s 67ms/step - loss: 1.2809 - accuracy: 0.5179 - val_loss: 1.3346 - val_accuracy: 0.4900
# Epoch 62/70
# 632/632 [==============================] - 42s 67ms/step - loss: 1.1834 - accuracy: 0.5560 - val_loss: 1.2325 - val_accuracy: 0.5415
# Epoch 63/70
# 632/632 [==============================] - 42s 67ms/step - loss: 1.1119 - accuracy: 0.5780 - val_loss: 1.1466 - val_accuracy: 0.5691
# Epoch 64/70
# 631/632 [============================>.] - ETA: 0s - loss: 1.0472 - accuracy: 0.6067
# Epoch 00064: saving model to ../training_2/cp-0064.ckpt
# 632/632 [==============================] - 43s 67ms/step - loss: 1.0473 - accuracy: 0.6066 - val_loss: 1.1178 - val_accuracy: 0.5744
# Epoch 65/70
# 632/632 [==============================] - 42s 67ms/step - loss: 0.9926 - accuracy: 0.6301 - val_loss: 1.0941 - val_accuracy: 0.5907
# Epoch 66/70
# 632/632 [==============================] - 43s 67ms/step - loss: 0.9433 - accuracy: 0.6484 - val_loss: 1.0483 - val_accuracy: 0.6120
# Epoch 67/70
# 632/632 [==============================] - 43s 67ms/step - loss: 0.8983 - accuracy: 0.6693 - val_loss: 1.0351 - val_accuracy: 0.6126
# Epoch 68/70
# 632/632 [==============================] - 43s 67ms/step - loss: 0.8569 - accuracy: 0.6835 - val_loss: 1.0570 - val_accuracy: 0.6075
# Epoch 69/70
# 631/632 [============================>.] - ETA: 0s - loss: 0.8187 - accuracy: 0.6998
# Epoch 00069: saving model to ../training_2/cp-0069.ckpt
# 632/632 [==============================] - 43s 68ms/step - loss: 0.8186 - accuracy: 0.6999 - val_loss: 0.9866 - val_accuracy: 0.6364
# Epoch 70/70
# 632/632 [==============================] - 43s 67ms/step - loss: 0.7792 - accuracy: 0.7162 - val_loss: 0.9778 - val_accuracy: 0.6430

# %%
acc += history.history['accuracy']
val_acc += history.history['val_accuracy']

loss += history.history['loss']
val_loss += history.history['val_loss']
plot_process(acc, val_acc, loss, val_acc)

# %%
index = 6
fine_tune_epochs = 30
total_epochs += fine_tune_epochs

history = model.fit(train_dataset, 
                    epochs=total_epochs, 
                    initial_epoch=history.epoch[-1], 
                    validation_data=val_dataset,
ckpt
# 632/632 [==============================] - 43s 68ms/step - loss: 0.2165 - accuracy: 0.9331 - val_loss: 0.7923 - val_accuracy: 0.7784
# Epoch 94/100
# 632/632 [==============================] - 43s 68ms/step - loss: 0.2047 - accuracy: 0.9377 - val_loss: 0.9236 - val_accuracy: 0.7424
# Epoch 95/100
# 632/632 [==============================] - 43s 68ms/step - loss: 0.1952 - accuracy: 0.9408 - val_loss: 0.7875 - val_accuracy: 0.7894
# Epoch 96/100
# 632/632 [==============================] - 43s 67ms/step - loss: 0.1814 - accuracy: 0.9457 - val_loss: 0.7507 - val_accuracy: 0.8012
# Epoch 97/100
# 632/632 [==============================] - 43s 68ms/step - loss: 0.1722 - accuracy: 0.9490 - val_loss: 0.7917 - val_accuracy: 0.7877
# Epoch 98/100
# 631/632 [============================>.] - ETA: 0s - loss: 0.1629 - accuracy: 0.9530
# Epoch 00098: saving model to ../training_2/cp-0098.ckpt
# 632/632 [==============================] - 43s 68ms/step - loss: 0.1628 - accuracy: 0.9530 - val_loss: 0.7649 - val_accuracy: 0.7957
# Epoch 99/100
# 632/632 [==============================] - 43s 67ms/step - loss: 0.1514 - accuracy: 0.9550 - val_loss: 0.7704 - val_accuracy: 0.7993
# Epoch 100/100
# 632/632 [==============================] - 43s 68ms/step - loss: 0.1398 - accuracy: 0.9596 - val_loss: 0.8170 - val_accuracy: 0.7914

# %%
acc += history.history['accuracy']
val_acc += history.history['val_accuracy']

loss += history.history['loss']
val_loss += history.history['val_loss']
plot_process(acc, val_acc, loss, val_loss)

# %%
index = 7
fine_tune_epochs = 30
total_epochs += fine_tune_epochs

history = model.fit(train_dataset, 
                    epochs=total_epochs, 
                    initial_epoch=history.epoch[-1], 
                    validation_data=val_dataset,
                   callbacks=[cp_callback])

histories[index] = history
# Out:
# Epoch 100/130
# 632/632 [==============================] - 42s 67ms/step - loss: 0.1315 - accuracy: 0.9614 - val_loss: 0.7882 - val_accuracy: 0.8066
# Epoch 101/130
# 632/632 [==============================] - 42s 67ms/step - loss: 0.1234 - accuracy: 0.9643 - val_loss: 0.8182 - val_accuracy: 0.8038
# Epoch 102/130
# 631/632 [============================>.] - ETA: 0s - loss: 0.1171 - accuracy: 0.9655
# Epoch 00102: saving model to ../training_2/cp-0102.ckpt
# 632/632 [==============================] - 43s 67ms/step - loss: 0.1171 - accuracy: 0.9654 - val_loss: 0.9010 - val_accuracy: 0.7796
# Epoch 103/130
# 632/632 [==============================] - 42s 67ms/step - loss: 0.1092 - accuracy: 0.9688 - val_loss: 0.8226 - val_accuracy: 0.8101
# Epoch 104/130
# 632/632 [==============================] - 42s 67ms/step - loss: 0.1063 - accuracy: 0.9711 - val_loss: 0.9433 - val_accuracy: 0.7783
# Epoch 105/130
# 632/632 [==============================] - 43s 67ms/step - loss: 0.0994 - accuracy: 0.9719 - val_loss: 1.0358 - val_accuracy: 0.7705
# Epoch 106/130
# 632/632 [==============================] - 43s 67ms/step - loss: 0.0937 - accuracy: 0.9735 - val_loss: 0.8315 - val_accuracy: 0.8130
# Epoch 107/130
# 631/632 [============================>.] - ETA: 0s - loss: 0.0885 - accuracy: 0.9754
# Epoch 00107: saving model to ../training_2/cp-0107.ckpt
# 632/632 [==============================] - 43s 68ms/step - loss: 0.0884 - accuracy: 0.9754 - val_loss: 0.8922 - val_accuracy: 0.8050
# Epoch 108/130
# 632/632 [==============================] - 42s 67ms/step - loss: 0.0820 - accuracy: 0.9770 - val_loss: 0.8804 - val_accuracy: 0.8021
# Epoch 109/130
# 632/632 [==============================] - 42s 67ms/step - loss: 0.0786 - accuracy: 0.9792 - val_loss: 0.8906 - val_accuracy: 0.8024
# Epoch 110/130
# 632/632 [==============================] - 43s 67ms/step - loss: 0.0733 - accuracy: 0.9796 - val_loss: 0.9945 - val_accuracy: 0.7887
# Epoch 111/130
# 632/632 [==============================] - 43s 67ms/step - loss: 0.0723 - accuracy: 0.9801 - val_loss: 0.8363 - val_accuracy: 0.8154
# Epoch 112/130
# 631/632 [============================>.] - ETA: 0s - loss: 0.0682 - accuracy: 0.9811
# Epoch 00112: saving model to ../training_2/cp-0112.ckpt
# 632/632 [==============================] - 43s 67ms/step - loss: 0.0682 - accuracy: 0.9811 - val_loss: 0.8844 - val_accuracy: 0.8132
# Epoch 113/130
# 632/632 [==============================] - 43s 67ms/step - loss: 0.0631 - accuracy: 0.9823 - val_loss: 0.8600 - val_accuracy: 0.8151
# Epoch 114/130
# 632/632 [==============================] - 43s 67ms/step - loss: 0.0597 - accuracy: 0.9834 - val_loss: 0.9340 - val_accuracy: 0.8020
# Epoch 115/130
# 632/632 [==============================] - 43s 67ms/step - loss: 0.0586 - accuracy: 0.9842 - val_loss: 0.9374 - val_accuracy: 0.8069
# Epoch 116/130
# 632/632 [==============================] - 43s 67ms/step - loss: 0.0542 - accuracy: 0.9861 - val_loss: 0.8639 - val_accuracy: 0.8205
# Epoch 117/130
# 631/632 [============================>.] - ETA: 0s - loss: 0.0523 - accuracy: 0.9862
# Epoch 00117: saving model to ../training_2/cp-0117.ckpt
# 632/632 [==============================] - 43s 68ms/step - loss: 0.0523 - accuracy: 0.9862 - val_loss: 0.9518 - val_accuracy: 0.8074
# Epoch 118/130
# 632/632 [==============================] - 43s 67ms/step - loss: 0.0523 - accuracy: 0.9861 - val_loss: 0.9095 - val_accuracy: 0.8109
# Epoch 119/130
# 632/632 [==============================] - 43s 67ms/step - loss: 0.0478 - accuracy: 0.9878 - val_loss: 0.9936 - val_accuracy: 0.8008
# Epoch 120/130
# 632/632 [==============================] - 43s 67ms/step - loss: 0.0460 - accuracy: 0.9876 - val_loss: 0.9258 - val_accuracy: 0.8159
# Epoch 121/130
# 632/632 [==============================] - 43s 67ms/step - loss: 0.0440 - accuracy: 0.9886 - val_loss: 0.9976 - val_accuracy: 0.8139
# Epoch 122/130
# 631/632 [============================>.] - ETA: 0s - loss: 0.0416 - accuracy: 0.9889
# Epoch 00122: saving model to ../training_2/cp-0122.ckpt
# 632/632 [==============================] - 43s 68ms/step - loss: 0.0416 - accuracy: 0.9889 - val_loss: 1.0102 - val_accuracy: 0.8055
# Epoch 123/130
# 632/632 [==============================] - 43s 67ms/step - loss: 0.0411 - accuracy: 0.9888 - val_loss: 1.0143 - val_accuracy: 0.8135
# Epoch 124/130
# 632/632 [==============================] - 43s 67ms/step - loss: 0.0405 - accuracy: 0.9889 - val_loss: 1.1128 - val_accuracy: 0.7936
# Epoch 125/130
# 632/632 [==============================] - 43s 67ms/step - loss: 0.0383 - accuracy: 0.9903 - val_loss: 0.9909 - val_accuracy: 0.8203
# Epoch 126/130
# 632/632 [==============================] - 43s 67ms/step - loss: 0.0368 - accuracy: 0.9908 - val_loss: 0.9908 - val_accuracy: 0.8185
# Epoch 127/130
# 631/632 [============================>.] - ETA: 0s - loss: 0.0358 - accuracy: 0.9904
# Epoch 00127: saving model to ../training_2/cp-0127.ckpt
# 632/632 [==============================] - 43s 68ms/step - loss: 0.0357 - accuracy: 0.9904 - val_loss: 0.9938 - val_accuracy: 0.8221
# Epoch 128/130
# 632/632 [==============================] - 43s 67ms/step - loss: 0.0352 - accuracy: 0.9904 - val_loss: 1.0131 - val_accuracy: 0.8145
# Epoch 129/130
# 632/632 [==============================] - 43s 67ms/step - loss: 0.0346 - accuracy: 0.9909 - val_loss: 1.0107 - val_accuracy: 0.8162
# Epoch 130/130
# 632/632 [==============================] - 43s 67ms/step - loss: 0.0307 - accuracy: 0.9924 - val_loss: 1.0883 - val_accuracy: 0.8046

# %%
acc += history.history['accuracy']
val_acc += history.history['val_accuracy']

loss += history.history['loss']
val_loss += history.history['val_loss']
plot_process(acc, val_acc, loss, val_loss)

# %%
import pickle
dict = {"acc":acc, "val_acc":val_acc, "loss":loss, "val_loss":val_loss}
f = open("../training_2/accurarcy-12-03.pkl","wb")
pickle.dump(dict,f)
f.close()

# %%
class_names = {0:'Angry', 1:"Disgust", 2:"Happy", 3:"Happy", 4:"Sad", 5:"Surprise", 6:"Neutral"}
plt.figure(figsize=(10, 10))
for images, labels in val_dataset.take(1):
    test_labels = model.predict(images)
    print(test_labels)
    for i in range(9):
#         print(np.argmax(labels[i].numpy()))
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title("GT:" + class_names[np.argmax(labels[i].numpy())] + "TS:")
        plt.axis("off")

# %%
base_model.trainable = True

model.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=False),
              optimizer = tf.keras.optimizers.RMSprop(lr=base_learning_rate),
              metrics=['accuracy'])

model.summary()

# %%
index = 3
fine_tune_epochs = 10
total_epochs =  total_epoches + fine_tune_epochs

history = model.fit(train_dataset, 
                    epochs=total_epochs, 
                    initial_epoch=history.epoch[-1], 
                    validation_data=val_dataset)

# %%
fine_tune_epochs = 3
total_epochs =  20
history= histories[2]

history = model.fit(train_dataset, 
                    epochs=total_epochs, 
                    initial_epoch=history.epoch[-1], 
                    validation_data=val_dataset,
                    callbacks=[cp_callback])

# %%
model.save_weights(checkpoint_path)
